# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("student_marks.csv")
data
# Out:
#   Student  Math  Science  English
# 0       A    78       85       82
# 1       B    65       70       72
# 2       C    88       92       90
# 3       D    56       60       58
# 4       E    91       89       94
# 5       F    73       75       70
# 6       G    84       80       79
# 7       H    69       72       68
# 8       I    95       94       96
# 9       J    62       65       60

# %%
mean_marks=df[["Math","Science","English"]].mean()

# %%
print("mean marks per subject:",(mean_marks))
# Out:
# mean marks per subject: Math       76.1
# Science    78.2
# English    76.9
# dtype: float64

# %%
median_marks=df[["Math","Science","English"]].median()

# %%
print("median of subject:",(median_marks))
# Out:
# median of subject: Math       75.5
# Science    77.5
# English    75.5
# dtype: float64

# %%
mode_marks=df[["Math","Science","English"]].mode()

# %%
print("mode of subject:",(mode_marks))
# Out:
# mode of subject:    Math  Science  English
# 0    56       60       58
# 1    62       65       60
# 2    65       70       68
# 3    69       72       70
# 4    73       75       72
# 5    78       80       79
# 6    84       85       82
# 7    88       89       90
# 8    91       92       94
# 9    95       94       96

# %%
range_marks=df[["Math","Science","English"]].max()-df[["Math","Science","English"]].min()

# %%
print(range_marks)
# Out:
# Math       39
# Science    34
# English    38
# dtype: int64

# %%
std=df[["Math","Science","English"]].std()

# %%
print(std)
# Out:
# Math       13.219934
# Science    11.679041
# English    13.551958
# dtype: float64

# %%
highest=df[["Math","Science","English"]].max()

# %%
print(highest)
# Out:
# Math       95
# Science    94
# English    96
# dtype: int64

# %%
lowest =df[["Math","Science","English"]].min()

# %%
print(lowest)
# Out:
# Math       56
# Science    60
# English    58
# dtype: int64

# %%
plt.figure()
df["Math"].plot(kind='bar')
plt.xlabel('Marks')
plt.ylabel('Frequency')
plt.title('Marks Distribution')
plt.show()
